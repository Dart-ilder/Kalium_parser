# %% [markdown]
# # ТЗ
# Выгрузить из Калиума все блокаторы с подтверждённой эксперементально селектиностью
# на любые два канала из Kv 1.1 - 1.3

# %%
# Ligand class definition

class Ligand(object):
    def __init__(self, uid, seq=None, pdb=None, mass=None, mode=None):
        self.uid = uid
        self.seq = seq
        self.pdb = pdb
        self.mass = mass
        self.mode = mode
        self.exp = dict()  # Catalog of known targets with indexed by channel's name

    def __str__(self):
        rep = str(self.uid) +"\t" + "PDB:" + str(self.pdb) + "\n"
        for i in self.exp:
            rep += "\t" + str(i) + "\t" + str(self.exp[i]) + "\n"
        return rep

    def addExperiment(self, target=None, data=None, method=None, testsys=None, species=None, act=None, doi=None):
        self.exp.update({target: [data, method, testsys, species, act, doi]})

# %%
# Reading the csv into kalium data structure
import csv
kalium = dict()  # Catalog of ligands indexed by UniProt ID
with open('export.csv', 'r') as file:
    reader = csv.reader(file)
    exp_read_flag = False
    for row in reader:
        if (row == []):
            kalium.update({lig.uid: lig})
            del lig
            exp_read_flag = False
        else:
            if (row[0] == "UniProt ID"):
                lig = Ligand(row[1])
            if (row[0] == "Sequence"):
                lig.seq = row[1] or None
            if (row[0] == "PDB"):
                lig.pdb = row[1] or None
            if (row[0] == "Mass"):
                lig.mass = row[1] or None
            if (row[0] == "Mode"):
                lig.mode = row[1] or None

            if (row[0] == "Target Channel"):
                exp_read_flag = True
                continue

            if (exp_read_flag):
                target = row[0] or None
                data = row[1] or None
                method = row[2] or None
                testsys = row[3] or None
                species = row[4] or None
                act = row[5] or None
                doi = row[6] or None
                lig.addExperiment(target, data, method,
                                  testsys, species, act, doi)

# %%
# Only ligands with activity relative to any 2 of kv1.1 - kv1.3
part = dict() 
for uid in kalium:
    targets = list(kalium[uid].exp.keys())
    if  ((("Kv1.1" in targets) and ("Kv1.3" in targets)) or 
            (("Kv1.1" in targets) and ("Kv1.2" in targets)) or
            (("Kv1.2" in targets) and ("Kv1.3" in targets))):
        part.update({uid: kalium[uid]})

print (len(part))
for i in part:
    print (part[i])
# Out:
# 120
# Q9PWF3	PDB:1H5O,1Z99
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '369', '22498659']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '386', '22498659']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '287', '22498659']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '22498659']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '22498659']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '>3000', '22498659']
#
# P00980	PDB:1DTX
# 	Kv1.1	['EC50', 'patch', 'mammal', 'mouse', '9,4', '9134213']
# 	Kv1.2	['EC50', 'volt', 'oocyte', 'rat', '0,38', '1921987']
# 	Kv1.3	['EC50', 'volt', 'oocyte', 'rat', '>100', '1921987']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>200', '2555158']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>200', '2361015']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '9', '2361015']
# 	Kv3.1	['IC50', 'patch', 'oocyte', 'rat', '>100', '1378392']
# 	Kv3.2	['IC50', 'patch', 'oocyte', 'rat', '>100', '1378392']
# 	Kv3.4	['IC50', 'patch', 'oocyte', 'rat', '>100', '1378392']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>300', '1722463']
# 	Kir1.1	['Kd', 'volt', 'oocyte', 'rat', '>150', '9778362']
#
# A0A1Z0YU59	PDB:5M4V
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '8200', '201620454']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv1.5	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv3.1	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv11.1	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
#
# P00981	PDB:1DTK
# 	Kv1	['Ki', 'radio', 'mammal', 'rat', '0,29', '10429207']
# 	Kv1.1	['EC50', 'patch', 'mammal', 'mouse', '0,03', '9134213']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>3', '8612784']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '>3', '8612784']
#
# P00979	PDB:1DEM,1DEN
# 	Kv1.1	['EC50', 'patch', 'mammal', 'mouse', '7,4', '9134213']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'mouse', '0,13', '7816560']
# 	Kv1.3	[None, 'patch', 'mammal', 'human', '>100', '8505626']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'human', '>1000', '9618407']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '10/26', '8612784']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>300', '1722463']
#
# P0C8R1	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>750', '18804453']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '10.4', '18804453']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '1.1', '18804453']
#
# P24662	PDB:1KTX,1XSW,2KTX,2UVS,3ODV
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '1.1', '20007782']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '20', '20007782']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '0.1', '20007782']
# 	KCa1.1	['Kd', 'volt', 'oocyte', 'mouse', '1560', '20007782']
#
# P0C166	PDB:None
# 	Shaker	['Kd', 'patch', 'mammal', 'fly', '10/20,0', '15615696']
# 	Kv1.1	['Kd', 'patch', 'mammal', 'mouse', '>10', '15615696']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'human', '6.14', '15615696']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '0.73', '15615696']
# 	Kv2.1	['Kd', 'patch', 'mammal', 'rat', '10/20,0', '15615696']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'human', '>10', '15615696']
#
# P0C908	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '3.5', '17490656']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '550/50', '17490656']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '550/50', '17490656']
#
# P84744	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '145', '15165720']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '2.5', '15165720']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '15', '15165720']
#
# C0HJQ2	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1000/100', '26398235']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '1000/100', '26398235']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '1000/100', '26398235']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '26398235']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '75.9', '26398235']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '26398235']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '1000/65', '26398235']
#
# P0DL62	PDB:None
# 	Kv1.1	[None, 'volt', 'oocyte', 'rat', '1000/32', '26079392']
# 	Kv1.2	[None, 'volt', 'oocyte', 'rat', '1000/100', '26079392']
# 	Kv1.3	[None, 'volt', 'oocyte', 'human', '1000/83', '26079392']
# 	Kv1.4	[None, 'volt', 'oocyte', 'rat', '>1000', '26079392']
# 	Kv1.6	[None, 'volt', 'oocyte', 'rat', '1000/21', '26079392']
# 	Shaker-IR	[None, 'volt', 'oocyte', 'fly', '1000/100', '26079392']
#
# P59847	PDB:1HLY
# 	Kv1.1	['IC50', 'flux', 'mammal', None, '0.031', '9446567']
# 	Kv1.2	['IC50', 'flux', 'mammal', None, '0.17', '9446567']
# 	Kv1.3	['IC50', 'flux', 'mammal', None, '0.086', '9446567']
# 	Kv1.6	['IC50', 'flux', 'mammal', None, '6', '9446567']
#
# P40755	PDB:1MTX
# 	Shaker	['Kd', None, None, 'fly', '160', '10.1023/A:1017062613503']
# 	Kv1.1	['Kd', 'patch', 'mammal', 'human', '4.2', '24878374']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'human', '0.006', '24878374']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '0.011', '24878374']
#
# P08815	PDB:1SXM
# 	Shaker	['Kd', None, None, 'fly', '160', '10.1023/A:1017062613503']
# 	Kv1.1	['Kd', 'patch', 'mammal', 'mouse', '>25', '7517498']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'rat', '2', '7517498']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'mouse', '1', '7517498']
# 	Kv1.5	['Kd', 'patch', 'mammal', 'human', '>25', '7517498']
# 	KCa1.1	['Kd', None, None, 'rat', '450', '10.1023/A:1017062613503']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'mouse', '>25', '7517498']
#
# O46028	PDB:1PJV
# 	Shaker	['Kd', 'patch', 'insect', 'fly', '700', '9688256']
# 	Kv1	['Ki', 'radio', 'mammal', 'rat', '0.109', '9688256']
# 	Kv1.1	['Kd', 'patch', 'mammal', 'mouse', '24400', '14498829']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'rat', '27', '14498829']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'mouse', '5300', '14498829']
# 	KCa2	['IC50', 'radio', 'mammal', 'rat', '7200', '14498829']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'human', '484', '14498829']
#
# P85529	PDB:None
# 	Kv1.1	['IC50', 'volt', 'mammal', 'mouse', '>10', '18786511']
# 	Kv1.2	['IC50', 'volt', 'mammal', 'human', '1.3', '18786511']
# 	Kv1.3	['IC50', 'volt', 'mammal', 'human', '7.2', '18786511']
# 	Kv1.4	['IC50', 'volt', 'mammal', 'human', '>10', '18786511']
# 	Kv1.5	['IC50', 'volt', 'mammal', 'human', '>10', '18786511']
# 	Kv2.1	['IC50', 'volt', 'mammal', 'rat', '>10', '18786511']
# 	Kv11.1	['IC50', 'volt', 'mammal', 'human', '>10', '18786511']
# 	KCa1.1	['IC50', 'volt', 'mammal', 'human', '>10', '18786511']
# 	KCa3.1	['IC50', 'volt', 'mammal', 'human', '>10', '18786511']
#
# C0HJW1	PDB:None
# 	Kv1.1	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Kv1.2	['IC50', 'volt', 'mammal', 'human', '0.3', '26921461']
# 	Kv1.3	['IC50', 'volt', 'mammal', 'human', '8.3', '26921461']
# 	KCa3.1	['IC50', 'volt', 'mammal', 'human', '6.4', '26921461']
# 	Shaker-IR	['IC50', 'volt', 'mammal', 'fly', '22', '26921461']
#
# C0HJW6	PDB:None
# 	Kv1.1	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Kv1.2	['IC50', 'volt', 'mammal', 'human', '0.7', '26921461']
# 	Kv1.3	['IC50', 'volt', 'mammal', 'human', '26.2', '26921461']
# 	KCa3.1	['IC50', 'volt', 'mammal', 'human', '~56', '26921461']
# 	Shaker-IR	['IC50', 'volt', 'mammal', 'fly', '>10', '26921461']
#
# C0HJW5	PDB:None
# 	Kv1.1	['IC50', 'volt', 'mammal', 'human', '4.8', '26921461']
# 	Kv1.2	['IC50', 'volt', 'mammal', 'human', '2.9', '26921461']
# 	Kv1.3	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	KCa3.1	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Shaker-IR	['IC50', 'volt', 'mammal', 'fly', '>10', '26921461']
#
# C0HJW2	PDB:None
# 	Kv1.1	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Kv1.2	['IC50', 'volt', 'mammal', 'human', '3.6', '26921461']
# 	Kv1.3	['IC50', 'volt', 'mammal', 'human', '~72', '26921461']
# 	KCa3.1	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Shaker-IR	['IC50', 'volt', 'mammal', 'fly', '>10', '26921461']
#
# C0HJW3	PDB:None
# 	Kv1.1	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Kv1.2	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Kv1.3	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Kv10.1	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Kv11.1	['IC50', 'volt', 'mammal', 'human', '16.9', '26921461']
# 	KCa3.1	['IC50', 'volt', 'mammal', 'human', '>10', '26921461']
# 	Shaker-IR	['IC50', 'volt', 'mammal', 'fly', '>10', '26921461']
#
# P0DJO5	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', None, '1000/7', '22580271']
# 	Kv1.2	['IC50', 'patch', 'mammal', None, '1000/22', '22580271']
# 	Kv1.3	['IC50', 'patch', 'mammal', None, '0.49', '22580271']
# 	Kv11.1	['IC50', 'patch', 'mammal', 'human', '10000/19', '22580271']
# 	KCa2.3	['IC50', 'patch', 'mammal', None, '1000/11', '22580271']
#
# P0DL47	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '>1000', '23262394']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '>1000', '23262394']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '950', '23262394']
#
# P85528	PDB:None
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '16', '18699777']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '13', '18699777']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '16', '18699777']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '2', '18699777']
#
# P82850	PDB:1HP9
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '>40000', '12034709']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '150000', '12034709']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '40000', '12034709']
#
# P0DJ41	PDB:None
# 	Kv1.1	['EC50', 'patch', 'mammal', 'rat', '9900', '22305749']
# 	Kv1.2	['EC50', 'patch', 'mammal', 'rat', '30000/4,8', '22305749']
# 	Kv1.3	['EC50', 'volt', 'oocyte', 'human', '30000/20,4', '22305749']
# 	Kv1.4	['EC50', 'patch', 'mammal', 'rat', '30000/12,9', '22305749']
# 	Kv1.5	['EC50', 'patch', 'mammal', 'rat', '30000/1,4', '22305749']
# 	Kv1.6	['EC50', 'patch', 'mammal', 'rat', '30000/59,8', '22305749']
# 	Kv1.8	['EC50', 'patch', 'mammal', 'rat', '30000/2,7', '22305749']
# 	Kv2.1	['EC50', 'patch', 'mammal', 'human', '30000/4', '22305749']
# 	Kv3.1	['EC50', 'patch', 'mammal', 'mouse', '30000/3,7', '22305749']
# 	Kv4.2	['EC50', 'patch', 'mammal', 'rat', '30000/2', '22305749']
# 	KCa2.3	['EC50', 'patch', 'mammal', 'human', '30000/2', '22305749']
# 	KCa3.1	['EC50', 'patch', 'mammal', 'human', '30000/3', '22305749']
#
# P59867	PDB:1QUZ,1WPD,1Y2P
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '0.001', '9359871']
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '7', '15498765']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'rat', '>100', '15498765']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '0.012', '9359871']
# 	Kv1.4	['IC50', 'patch', 'mammal', 'human', '>100', '16247791']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'human', '>100', '16247791']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '5000/35', '18687312']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'human', '>100', '16247791']
# 	KCa2	['IC50', 'radio', 'mammal', 'rat', '>1000', '9359871']
# 	KCa2.2	['IC50', 'patch', 'mammal', 'rat', '>100', '16247791']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '625', '15498765']
#
# P83655	PDB:None
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '>1000000', '15670585']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '>1000000', '15670585']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '>1000000', '15670585']
#
# P0C8W3	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '1000/45', '22354971']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '1000/50', '22354971']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '6.2', '22354971']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'mouse', '>1000', '22354971']
# 	KCa2.3	['IC50', 'patch', 'mammal', 'human', '1000/20', '22354971']
#
# P0DJL0	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '10000/40', '21308893']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '10000/42', '21308893']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '1700', '21308893']
#
# P13487	PDB:1BAH,1CMR,2A9H,2CRD,4JTA,4JTC,4JTD
# 	Shaker	['Ki', 'volt', 'oocyte', 'fly', '227', '8204618']
# 	Kv1.1	['Ki', 'volt', 'oocyte', 'rat', '1500', '8204618']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '9', '20007782']
# 	Kv1.3	['Ki', 'volt', 'oocyte', 'rat', '0.19', '8204618']
# 	Kv1.6	['Ki', 'volt', 'oocyte', 'rat', '22', '8204618']
# 	Kv2.1	['Ki', 'volt', 'oocyte', 'rat', '>2000', '8204618']
# 	KCa1.1	['Kd', 'volt', 'oocyte', 'mouse', '3.5', '20007782']
# 	KCa3.1	['Kd', None, None, 'human', '5', '10.1023/A:1017062613503']
#
# P46111	PDB:1AGT
# 	Shaker	['Ki', 'volt', 'oocyte', 'fly', '0.64', '8204618']
# 	Kv1.1	['Ki', 'volt', 'oocyte', 'rat', '0.044', '8204618']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '3.4', '20007782']
# 	Kv1.3	['Ki', 'volt', 'oocyte', 'rat', '0.004', '8204618']
# 	Kv1.6	['Ki', 'volt', 'oocyte', 'rat', '0.037', '8204618']
# 	Kv2.1	['Ki', 'volt', 'oocyte', 'rat', '>2000', '8204618']
#
# P46110	PDB:None
# 	Shaker	['Ki', 'volt', 'oocyte', 'fly', '0.16', '8204618']
# 	Kv1.1	['Ki', 'volt', 'oocyte', 'rat', '136', '8204618']
# 	Kv1.3	['Ki', 'volt', 'oocyte', 'rat', '1.7', '8204618']
# 	Kv1.6	['Ki', 'volt', 'oocyte', 'rat', '149', '8204618']
# 	Kv2.1	['Ki', 'volt', 'oocyte', 'rat', '>2000', '8204618']
#
# P0CH12	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', None, '1700', '19103241']
# 	Kv1.2	['IC50', 'patch', 'mammal', None, '12500', '19103241']
# 	Kv1.3	['IC50', 'patch', 'mammal', None, '28', '19103241']
#
# C0HJQ8	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '2110', '30248306']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '0.19', '30248306']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '67', '30248306']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '8900', '30248306']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>1000', '30248306']
#
# C0HJQ7	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '130', '30248306']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '3.1', '30248306']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '78', '30248306']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '910', '30248306']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>1000', '30248306']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>1000', '30248306']
#
# P86396	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '2000/19', '20713119']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '0.203', '20713119']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '8.92', '20713119']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '0.171', '20713119']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>2000', '20713119']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>2000', '20713119']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '2000/93', '20713119']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '20713119']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>2000', '20713119']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '20713119']
#
# C0HJQ4	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '90.3', '25792741']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '2677.7', '10.1134/S0869813919110074']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '311.7', '10.1134/S0869813919110074']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '10.1134/S0869813919110074']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '10.1134/S0869813919110074']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '266.3', '10.1134/S0869813919110074']
#
# C0HJQ6	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1.9', '25792741']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '106', '10.1134/S0869813919110074']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '8.9', '10.1134/S0869813919110074']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '10.1134/S0869813919110074']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '10.1134/S0869813919110074']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '63.4', '10.1134/S0869813919110074']
#
# P86400	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '3000/50', '20889474']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '3000/35', '20889474']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '2.36', '20889474']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '20889474']
#
# D3JXM1	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '>2000', '21466856']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>2000', '21466856']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>2000', '21466856']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '2000/20', '21466856']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>2000', '21466856']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>2000', '21466856']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>2000', '21466856']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '21466856']
# 	KCa1.1	['IC50', 'volt', 'mammal', 'human', '>2000', '21466856']
#
# P86399	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '12300', '23721518']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>10000', '23721518']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>10000', '23721518']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '>10000', '23721518']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>10000', '23721518']
#
# Q9NII7	PDB:1BKT,2K4U,2MLA,2MLD
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '2000/21', '20713119']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '0.2', '9354615']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '2000/100', '20713119']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '2000/73', '20713119']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '2000/100', '20713119']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>2000', '20713119']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>2000', '20713119']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '2000/91', '20713119']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '20713119']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>2000', '20713119']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '20713119']
#
# Q9U8D2	PDB:1WM7
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '3000/70', '20889474']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '467', '20889474']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '133', '20889474']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '20889474']
# 	KCa2	['Kd', 'radio', 'mammal', 'rat', '1000/4', '9151979']
#
# Q9NJP7	PDB:1DU9
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '20440', '22239942']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1950', '22239942']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '4400', '22239942']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '7', '22239942']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '22239942']
# 	KCa2	['Kd', 'radio', 'mammal', 'rat', '1000/12', '9151979']
#
# Q9U8D1	PDB:1WM8
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '4640', '22239942']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '5480', '22239942']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '530', '22239942']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '85.4', '22239942']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '22239942']
# 	KCa2	['Kd', 'radio', 'mammal', 'rat', '1000/42', '9151979']
#
# B5KF99	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '1000/20', '18571286']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '26.4', '18571286']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '0.8', '18571286']
# 	KCa2.2	['IC50', 'patch', 'mammal', 'human', '10000/24', '18571286']
# 	KCa2.3	['IC50', 'patch', 'mammal', 'human', '10000/27', '18571286']
#
# Q8I0L5	PDB:None
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '>5000', '14599291']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '>5000', '14599291']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '>5000', '14599291']
# 	Kv7.1	['Kd', 'volt', 'oocyte', 'human', '>5000', '14599291']
# 	Kv11.1	['Kd', 'volt', 'oocyte', 'human', '1900', '14599291']
#
# P83407	PDB:1Q2K,1R1G,3E8Y
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>100', '15178692']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>100', '15178692']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '>100', '15178692']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>100', '15178692']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'human', '>10000', '15178692']
# 	KCa2.2	['IC50', 'patch', 'mammal', 'rat', '1000/62', '15178692']
#
# P0DL65	PDB:2RTZ
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>50000', '25514171']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '15.6', '25514171']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '12500', '25514171']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '0.054', '25514171']
#
# P0C909	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '>35', '18471844']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>35', '18471844']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>35', '18471844']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '7.2', '18471844']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>35', '18471844']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>35', '18471844']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>35', '18471844']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>35', '18471844']
#
# P0CC12	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '>400', '17070524']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>400', '17070524']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '183', '17070524']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '>400', '17070524']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>400', '17070524']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>400', '17070524']
#
# P86110	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '>250000', '21624408']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>250000', '21624408']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>250000', '21624408']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '>250000', '21624408']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>250000', '21624408']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>250000', '21624408']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>250000', '21624408']
# 	Kv1.8	['IC50', 'volt', 'oocyte', 'rat', '>250000', '21624408']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>250000', '21624408']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>250000', '21624408']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>250000', '21624408']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>250000', '21624408']
#
# P0C1Z4	PDB:1WQE
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '500000/33', '15631621']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '500000/8', '15631621']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '500000/70', '15631621']
#
# P55896	PDB:1SCO,2CK4,2CK5
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '0.6', '15588251']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '5.4', '15588251']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '0.014', '15588251']
# 	Kv1.4	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	Kv1.6	['IC50', 'patch', 'mammal', None, '>1000', '15588251']
# 	Kv1.7	['IC50', 'patch', 'mammal', 'mouse', '>1000', '15588251']
# 	Kv3.1	['IC50', 'patch', 'mammal', 'mouse', '>1000', '15588251']
# 	Kv3.2	['IC50', 'patch', 'mammal', 'rat', '>1000', '16234482']
# 	Kv11	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	KCa2.1	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	KCa2.2	['IC50', 'patch', 'mammal', 'rat', '>1000', '15588251']
# 	KCa2.3	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '225', '15588251']
#
# A0A1L2FZD4	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '28179135']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '331', '28179135']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '503', '28179135']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '28179135']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '28179135']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '9983', '28179135']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '28179135']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>1000', '28179135']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>1000', '28179135']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>1000', '28179135']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '>1000', '28179135']
#
# P83244	PDB:None
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '>250', '11527374']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '97', '11527374']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '>250', '11527374']
#
# Q10726	PDB:1WZ5
# 	Shaker	['Kd', 'patch', 'insect', 'fly', '32', '9001397']
# 	Kv1	['IC50', 'flux', 'mammal', 'rat', '100', '8913348']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>5000', '10931199']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '0.44', '10931199']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '9.7', '9464266']
# 	KCa2.2	['Kd', 'patch', 'mammal', 'human', '100', '11527975']
# 	KCa2.3	['Kd', 'patch', 'mammal', 'human', '250', '11527975']
#
# P58498	PDB:1N8M
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '3', '12919322']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>10000', '12919322']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '0.008', '12919322']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '>10000', '12919322']
# 	KCa2	['IC50', 'volt', 'mammal', 'rat', '500', '12919322']
#
# P55927	PDB:2PTA
# 	Shaker	['Kd', 'patch', 'insect', 'fly', '8.2', '8660410']
# 	Kv1	['IC50', 'flux', 'mammal', 'rat', '6', '8913348']
# 	Kv1.2	['IC50', 'volt', 'mammal', None, '0.032', '8913348']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '0.044', '11155206']
#
# C0HKB2	PDB:None
# 	Shaker	['Kd', 'patch', 'insect', 'fly', '540', '28502745']
# 	Kv1.1	['Kd', 'patch', 'mammal', 'human', '>100', '28502745']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'human', '92', '28502745']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '77', '28502745']
# 	Kv1.4	['Kd', 'patch', 'mammal', 'human', '>100', '28502745']
# 	Shab	['Kd', 'patch', 'insect', 'fly', '>1500', '28502745']
#
# C0HKB3	PDB:None
# 	Shaker	['Kd', 'patch', 'insect', 'fly', '>100', '28502745']
# 	Kv1.1	['Kd', 'patch', 'mammal', 'human', '>100', '28502745']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'human', '100/31', '28502745']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '100/22', '28502745']
# 	Kv1.4	['Kd', 'patch', 'mammal', 'human', '>100', '28502745']
# 	Shab	['Kd', 'patch', 'insect', 'fly', '>100', '28502745']
#
# P83112	PDB:None
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '79000', '11952787']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '547', '11952787']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '492', '11952787']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>5000', '18687312']
#
# P60164	PDB:None
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '21000', '14561751']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '1000', '14561751']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '800', '14561751']
#
# P80719	PDB:1TXM,1WPD,1WT7
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '2.4', '10888198']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '0.2', '9022673']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '45', '9136903']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '0.8', '9136903']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '180', '9136903']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'human', '>1000', '12527813']
# 	KCa2	['IC50', 'radio', 'mammal', 'rat', '5', '9022673']
# 	KCa2.2	['Kd', 'patch', 'mammal', 'human', '1000', '11527975']
# 	KCa2.3	['Kd', 'patch', 'mammal', 'human', '>1000', '11527975']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '1', '12527813']
#
# P0DQN4	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '1000/21', '29142737']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '1000/7', '29142737']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '24.73', '29142737']
#
# P0DQN5	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '485', '31890149']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'mouse', '57', '31890149']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '14,7', '31890149']
#
# P46114	PDB:1HP2
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '1000/97', '24590385']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1000/85', '24590385']
# 	Kv1.2	['Kd', None, None, 'mouse', '0.2', '10.1023/A:1017062613503']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '1000/85', '24590385']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '1000/94', '24590385']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv7.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv7.2	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>5000', '18687312']
#
# P59936	PDB:1C55,1C56,1WT7
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '1000/80', '24590385']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '46', '12630699']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1000/9', '24590385']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '6.19', '24590385']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '0.55', '24590385']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '1000/25', '24590385']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '1000/20', '24590385']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv7.1	['IC50', 'volt', 'oocyte', 'rat', '1000/5', '24590385']
# 	Kv7.2	['IC50', 'volt', 'oocyte', 'rat', '1000/14', '24590385']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '1000/11', '24590385']
#
# P86270	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '500/20', '21600910']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '500/10', '21600910']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '196', '21600910']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '508', '21600910']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>500', '21600910']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '500/10', '21600910']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '500/20', '21600910']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>500', '21600910']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '500/5', '21600910']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>500', '21600910']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>500', '21600910']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>500', '21600910']
#
# P69940	PDB:None
# 	Kv1	['IC50', 'flux', 'mammal', 'rat', '30', '7509073']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '652', '27346450']
# 	Kv7.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv7.2	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv7.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv7.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '27346450']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'human', '>1000', '27346450']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '>1000', '27346450']
#
# P0C174	PDB:2MSF
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '3000/25', '27706049']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '17100', '27706049']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '27706049']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '3000/25', '27706049']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'human', '3000/15', '27706049']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '3000/12', '27706049']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '3000/10', '27706049']
#
# P0C175	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '3000/5', '27706049']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '3000/10', '27706049']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '3000/20', '27706049']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '27706049']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '27706049']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '3000/24', '27706049']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '3000/27', '27706049']
#
# P0CB56	PDB:None
# 	Kv1.1	['Kd', 'patch', 'mammal', 'mouse', '>10', '19500613']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'human', '1.9', '19500613']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '10.7', '19500613']
# 	Kv1.4	['Kd', 'patch', 'mammal', 'human', '>10', '19500613']
# 	Kv1.5	['Kd', 'patch', 'mammal', 'human', '>10', '19500613']
# 	Kv11.1	['Kd', 'patch', 'mammal', 'human', '>10', '19500613']
# 	KCa1.1	['Kd', 'patch', 'mammal', 'human', '>10', '19500613']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'human', '>10', '19500613']
#
# P0C168	PDB:None
# 	Shaker	['Kd', 'patch', 'insect', 'fly', '660', '12565736']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '46', '12630699']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1000/9', '24590385']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '6.19', '24590385']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '0.55', '24590385']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '1000/25', '24590385']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '1000/20', '24590385']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv7.1	['IC50', 'volt', 'oocyte', 'rat', '1000/5', '24590385']
# 	Kv7.2	['IC50', 'volt', 'oocyte', 'rat', '1000/14', '24590385']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '1000/11', '24590385']
#
# P0C183	PDB:None
# 	Shaker	['EC50', 'volt', 'oocyte', 'fly', '>500', '16405970']
# 	Kv1.1	['EC50', 'volt', 'oocyte', 'rat', '>500', '16405970']
# 	Kv1.2	['EC50', 'volt', 'oocyte', 'rat', '102', '16405970']
# 	Kv1.3	['EC50', 'volt', 'oocyte', 'human', '7.9', '16405970']
# 	Kv1.4	['EC50', 'volt', 'oocyte', 'rat', '>500', '16405970']
# 	Kv1.5	['EC50', 'volt', 'oocyte', 'rat', '>500', '16405970']
# 	Kv11.1	['EC50', 'volt', 'oocyte', 'human', '>500', '16405970']
#
# P0DL37	PDB:6MZT
# 	Kv1.1	['IC50', 'patch', 'mammal', 'human', '253', '24723491']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '0.16', '24723491']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'human', '91', '24723491']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'human', '>10', '24723491']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '70', '24723491']
#
# P0DJ31	PDB:2K9O
# 	Kv1.1	['Kd', 'volt', 'mammal', 'mouse', '0.8', '22622363']
# 	Kv1.2	['Kd', 'volt', 'mammal', 'human', '0.54', '22622363']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '0.003', '22622363']
# 	Kv1.4	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	Kv1.5	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	Kv2.1	['Kd', 'volt', 'mammal', 'rat', '>10', '22622363']
# 	Kv11.1	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	KCa1.1	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	KCa2.3	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	KCa3.1	['Kd', 'volt', 'mammal', 'human', '0.59', '22622363']
#
# P0DJ32	PDB:None
# 	Kv1.1	['Kd', 'volt', 'mammal', 'mouse', '10/0', 'WO2008139243A1']
# 	Kv1.2	['Kd', 'volt', 'mammal', 'human', '10/9,8', 'WO2008139243A1']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '10/100', 'WO2008139243A1']
# 	KCa3.1	['Kd', 'volt', 'mammal', 'human', '10/0', 'WO2008139243A1']
#
# Q2PAY4	PDB:None
# 	Kv	[None, 'patch', 'mammal', 'rat', '52,3', '20571743']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>10000', '17157888']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>10000', '17157888']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>10000', '17157888']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '5000/35', '17150181']
# 	Kv4.1	['IC50', 'volt', 'oocyte', None, '5000/25', '17150181']
# 	Kv4.2	['IC50', 'volt', 'oocyte', None, '604,2', '17157888']
# 	Kv4.3	['IC50', 'volt', 'oocyte', None, '425,1', '20571743']
#
# P84835	PDB:2WH9
# 	Kv1.2	['Kd', 'volt', 'mammal', 'human', '>4000', '16567526']
# 	Kv1.3	['Kd', 'volt', 'mammal', 'human', '>4000', '16567526']
# 	Kv1.5	['Kd', 'volt', 'mammal', 'human', '>4000', '16567526']
# 	Kv2.1	['Kd', 'volt', 'mammal', 'human', '5,1', '16567526']
# 	Kv2.2	['Kd', 'volt', 'mammal', 'human', '2,6', '16567526']
# 	Kv3.2	['Kd', 'volt', 'mammal', 'human', '>4000', '16567526']
# 	Kv4.3	['Kd', 'volt', 'mammal', 'human', '54', '16567526']
#
# P83974	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>1000', '15548530']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>1000', '15548530']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>1000', '15548530']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '8050', '23246579']
#
# P62520	PDB:2I1T
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>1000', '15084603']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>1000', '15084603']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>1000', '15084603']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '5000/95', '17150181']
#
# P0C5X7	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>10000', '17631373']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>10000', '17631373']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>10000', '17631373']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>10000', '17631373']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '1000/9', '17631373']
# 	Kv3.1	['IC50', 'volt', 'oocyte', None, '>10000', '17631373']
# 	Kv4.1	['IC50', 'volt', 'oocyte', None, '363', '17631373']
# 	Kv4.2	['IC50', 'volt', 'oocyte', None, '1000/15', '17631373']
#
# P0C247	PDB:2A2V
# 	Kv1.1	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv1.2	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv1.3	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv1.4	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv2.1	['Kd', 'volt', 'oocyte', None, '760', '17176080']
# 	Kv3.1	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv4.1	['Kd', 'volt', 'oocyte', None, '5000/35', '17176080']
# 	Kv4.2	['Kd', 'volt', 'oocyte', None, '5000/42', '17176080']
#
# B1P1F5	PDB:None
# 	Kv1.1	['Kd', 'volt', 'oocyte', None, '>10000', '19409400']
# 	Kv1.2	['Kd', 'volt', 'oocyte', None, '>10000', '19409400']
# 	Kv1.3	['Kd', 'volt', 'oocyte', None, '>10000', '19409400']
# 	Kv2.1	['Kd', 'volt', 'oocyte', None, '3300', '19409400']
#
# P56852	PDB:1D1H
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>500', '7576642']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>500', '7576642']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '>500', '7576642']
# 	Kv2.1	['Kd', 'volt', 'oocyte', 'human', '102', '9136775']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'mouse', '>500', '7576642']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '100', '9136775']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'fly', '>500', '7576642']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '6000', '9136775']
#
# P68425	PDB:2JOT
# 	Kv1	['IC50', 'patch', 'mammal', 'rat', '11,6', '18923708']
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '5000/78', '18923708']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '5000/10', '18923708']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '5000/28', '18923708']
#
# P60993	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '300/10', '12065754']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'mouse', '300/1', '12065754']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '300/6', '12065754']
# 	Kv1.4	['IC50', 'patch', 'mammal', 'mouse', '300/6', '12065754']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'mouse', '300/1', '12065754']
# 	Kv1.6	['IC50', 'patch', 'mammal', 'mouse', '300/13', '12065754']
# 	Kv2.1	['IC50', 'patch', 'mammal', 'mouse', '300/18', '12065754']
# 	Kv2.2	['IC50', 'patch', 'mammal', 'mouse', '>300', '12065754']
# 	Kv3.4	['IC50', 'patch', 'mammal', 'mouse', '300/2', '12065754']
# 	Kv4.1	['IC50', 'patch', 'mammal', 'mouse', '>100', '12065754']
# 	Kv4.2	['IC50', 'patch', 'mammal', 'mouse', '>100', '12065754']
# 	Kv4.3	['IC50', 'patch', 'mammal', 'mouse', '>100', '12065754']
# 	Kv7.1	['IC50', 'patch', 'mammal', 'mouse', '300/4', '12065754']
#
# P60992	PDB:2N6O
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '300/12', '12065754']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'mouse', '300/4', '12065754']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '300/3', '12065754']
# 	Kv1.4	['IC50', 'patch', 'mammal', 'mouse', '300/4', '12065754']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'mouse', '300/2', '12065754']
# 	Kv1.6	['IC50', 'patch', 'mammal', 'mouse', '300/1', '12065754']
# 	Kv2.1	['IC50', 'patch', 'mammal', 'mouse', '100/23', '12065754']
# 	Kv2.2	['IC50', 'patch', 'mammal', 'mouse', '100/19,7', '12065754']
# 	Kv3.4	['IC50', 'patch', 'mammal', 'mouse', '300/4', '12065754']
# 	Kv4.1	['IC50', 'patch', 'mammal', 'mouse', '280', '12065754']
# 	Kv4.2	['IC50', 'patch', 'mammal', 'mouse', '300/39', '12065754']
# 	Kv4.3	['IC50', 'patch', 'mammal', 'mouse', '300/43', '12065754']
# 	Kv7.1	['IC50', 'patch', 'mammal', 'mouse', '300/8', '12065754']
#
# P61231	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.5	['IC50', 'patch', 'mammal', None, '>5000', '10051143']
# 	Kv2.1	['IC50', 'patch', 'mammal', None, '500/8', '10051143']
# 	Kv2.2	['IC50', 'patch', 'mammal', None, '500/11', '10051143']
# 	Kv3.1	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	Kv3.2	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	Kv3.4	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	Kv4.1	['IC50', 'patch', 'mammal', 'mouse', '300/200', '10051143']
# 	Kv4.2	['IC50', 'patch', 'mammal', 'rat', '34', '10051143']
# 	Kv4.3	['IC50', 'patch', 'mammal', 'rat', '71', '10051143']
# 	Kir2.1	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	K2p2.1	['IC50', 'patch', 'mammal', None, '>1000', '10051143']
#
# P61230	PDB:1V7F
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.5	['IC50', 'patch', 'mammal', None, '>5000', '10051143']
# 	Kv2.1	['IC50', 'patch', 'mammal', None, '500/6', '10051143']
# 	Kv2.2	['IC50', 'patch', 'mammal', None, '500/16', '10051143']
# 	Kv3.1	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	Kv3.2	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	Kv3.4	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	Kv4.1	['IC50', 'patch', 'mammal', 'mouse', '250/39', '10051143']
# 	Kv4.2	['IC50', 'patch', 'mammal', 'rat', '5', '10051143']
# 	Kv4.3	['IC50', 'patch', 'mammal', 'rat', '28', '10051143']
# 	Kv7.1	['IC50', 'patch', 'mammal', None, '>300', '10051143']
# 	Kv11.1	['IC50', 'patch', 'mammal', None, '>300', '10051143']
# 	Kir2.1	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	K2p2.1	['IC50', 'patch', 'mammal', None, '>1000', '10051143']
#
# P60991	PDB:None
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '300/8', '12065754']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'mouse', '300/10', '12065754']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '300/9', '12065754']
# 	Kv1.4	['IC50', 'patch', 'mammal', 'mouse', '400/4', '12065754']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'mouse', '>300', '12065754']
# 	Kv1.6	['IC50', 'patch', 'mammal', 'mouse', '>300', '12065754']
# 	Kv2.1	['IC50', 'patch', 'mammal', 'mouse', '7,2', '12065754']
# 	Kv2.2	['IC50', 'patch', 'mammal', 'mouse', '21,4', '12065754']
# 	Kv3.4	['IC50', 'patch', 'mammal', 'mouse', '300/4', '12065754']
# 	Kv4.1	['IC50', 'patch', 'mammal', 'mouse', '>100', '12065754']
# 	Kv4.2	['IC50', 'patch', 'mammal', 'mouse', '1,2', '12065754']
# 	Kv4.3	['IC50', 'patch', 'mammal', 'mouse', '>100', '12065754']
# 	Kv7.1	['IC50', 'patch', 'mammal', 'mouse', '300/19', '12065754']
#
# P83480	PDB:2M9L
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '730/6', '12475222']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '730/40', '12475222']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '730/7', '12475222']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'human', '730/60', '12475222']
#
# P83476	PDB:2N9T,5O0U,5TCZ
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '>460', '12475222']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '460/2', '12475222']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '460/-2', '12475222']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'human', '460/5', '12475222']
#
# C0HJD9	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '672', '30275388']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '167', '30275388']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '3000/20', '30275388']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '30275388']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '30275388']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '116', '30275388']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '30275388']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '30275388']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>3000', '30275388']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>3000', '30275388']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '30275388']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '3000/15', '30275388']
#
# P11494	PDB:1BDS,2BDS
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '10000/19', '9506974']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '10000/17', '9506974']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv1.5	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv2.2	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv3.1	['IC50', 'volt', 'oocyte', None, '10000/22', '9506974']
# 	Kv3.2	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv3.3	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv3.4	['IC50', 'volt', 'mammal', None, '47', '9506974']
# 	Kv4.2	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv4.3	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kir1.1	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kir2.1	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kir2.2	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
#
# P86862	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '>1000', '21477583']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '0,9', '21477583']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>1000', '21477583']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '>1000', '21477583']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '21477583']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '21477583']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>1000', '21477583']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '21477583']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '21477583']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>1000', '21477583']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>1000', '21477583']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>1000', '21477583']
#
# P61541	PDB:1WQK
# 	Kv1.1	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv1.2	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv1.3	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv1.4	['IC50', 'patch', 'mammal', None, '1000/35', '12815161']
# 	Kv1.5	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv1.6	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv2.1	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv3.4	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv4.2	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv7.1	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv7.2	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv7.3	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv10.1	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv11.1	['IC50', 'patch', 'mammal', None, '34', '12815161']
# 	Kv11.2	['Kd', 'volt', 'oocyte', None, '>1000', '17473056']
# 	Kv12.3	['IC50', 'patch', 'mammal', None, '>100', '12815161']
#
# C0HL40	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'human', '>1600', '28902151']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '1600/27', '28902151']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'human', '1600/66', '28902151']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '1600/17', '28902151']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'human', '1600/39', '28902151']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'human', '1100', '28902151']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>1600', '28902151']
#
# C0HJC4	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '3000/54', '23895459']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '172,59', '23895459']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '1006,68', '23895459']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23895459']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23895459']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '2245,93', '23895459']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23895459']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '23895459']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23895459']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23895459']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '23895459']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '94,25', '23895459']
#
# C0HJC3	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '14,42', '23466933']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '80,4', '23466933']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '13,12', '23466933']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23466933']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23466933']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '7,76', '23466933']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23466933']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23466933']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23466933']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>3000', '23466933']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '23466933']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '49,14', '23466933']
#
# C0HJC2	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '405', '23466933']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '0,03', '23466933']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '74', '23466933']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>500', '23466933']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>500', '23466933']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '1,31', '23466933']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>500', '23466933']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>500', '23466933']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>500', '23466933']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>500', '23466933']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>500', '23466933']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '247,69', '23466933']
#
# P29186	PDB:1BGK
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'human', '6', '9063464']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'human', '15', '9063464']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '10', '9063464']
# 	Kv3.1	['Kd', 'volt', 'oocyte', 'human', '>125', '9063464']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'human', '172', '10419508']
#
# O16846	PDB:None
# 	Shaker	['Ki', 'volt', 'oocyte', 'fly', '1', '26627718']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '3,2', '9298966']
# 	Kv1.2	['Ki', 'volt', 'oocyte', 'human', '2,5', '26627718']
# 	Kv1.3	['Ki', 'volt', 'oocyte', 'human', '3,1', '26627718']
#
# C0HK75	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
# 	Kv3.1	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
# 	Kv4.2	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
# 	Kv10.1	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', None, '>5000', '29414882']
#
# P29187	PDB:1BEI,1C2U,1ROO,2K9E,4LFQ,4LFS,4Z7P,5I5A,5I5B,5I5C
# 	Shaker	['Ki', 'volt', 'oocyte', 'fly', '2', '26627718']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '0,02', '7660365']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'mouse', '0,016', '9830012']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '9', '9830012']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'mouse', '0,011', '9830012']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'mouse', '0,312', '9830012']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '>100', '9830012']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'human', '0,165', '9830012']
# 	Kv1.7	['IC50', 'volt', 'oocyte', 'mouse', '11,5', '9830012']
# 	Kv2.1	['IC50', 'patch', 'mammal', 'human', '>1000', '15709110']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'mouse', '>100', '9830012']
# 	Kv3.2	['IC50', 'patch', 'mammal', 'human', '6', '15709110']
# 	Kv3.4	['IC50', 'volt', 'oocyte', 'rat', '>100', '9830012']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'human', '172', '10419508']
# 	KcsA-Shaker	['Ki', 'volt', 'oocyte', None, '50', '26627718']
#
# B3SVF1	PDB:None
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>30000', '18505731']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>50000', '18505731']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>50000', '18505731']
# 	Kv1.5	['IC50', 'volt', 'oocyte', None, '>50000', '18505731']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '8800', '18505731']
#
# Q0N4U8	PDB:2FQC,2NAV,2NAW
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.5	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '1590', '16819832']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '>2000', '16819832']
# 	Kv3.4	['IC50', 'volt', 'oocyte', None, '>2000', '16819832']
#
# B3SVF0	PDB:None
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '2000', '18505731']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>50000', '18505731']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>50000', '18505731']
# 	Kv1.5	['IC50', 'volt', 'oocyte', None, '>5000', '18505731']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '170', '18505731']
#
# P69769	PDB:None
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '1210', '12399472']
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>10000', '12399472']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '280', '15208025']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>10000', '12399472']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>10000', '12399472']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>5000', '15208025']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '5000/10', '15208025']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '>10000', '12399472']
# 	Kv3.4	['IC50', 'volt', 'oocyte', None, '>10000', '12399472']
# 	Kv4.2	['IC50', 'volt', 'oocyte', None, '>10000', '12399472']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'rat', '>10000', '12399472']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>10000', '12399472']
# 	KCa1.1	['IC50', 'volt', 'oocyte', 'human', '100000/0', '20220134']
# 	Kv7.2/Kv7.3	['IC50', 'volt', 'oocyte', 'human', '100000/0', '20220134']
# 	Kv1.2/Kv1.1	['IC50', 'volt', 'oocyte', 'human', '2800', '20220134']
# 	Kv1.2/Kv1.5	['IC50', 'volt', 'oocyte', 'human', '2760', '20220134']
# 	Kv1.2/Kv1.6	['IC50', 'volt', 'oocyte', 'human', '7740', '20220134']
# 	Kv1.2/Kv1.7	['IC50', 'volt', 'oocyte', 'human', '680', '20220134']
# 	TSha1	['IC50', 'volt', 'oocyte', 'trout', '65', '12399472']
#
# P0CG45	PDB:None
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '~4000', '20220134']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '33', '20220134']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '~10000', '20220134']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'human', '70000/0', '20220134']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '~70000', '20220134']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'human', '~8000', '20220134']
# 	KCa1.1	['IC50', 'volt', 'oocyte', 'human', '70000/0', '20220134']
# 	Kv7.2/Kv7.3	['IC50', 'volt', 'oocyte', 'human', '70000/0', '20220134']
# 	Kv1.2/Kv1.1	['IC50', 'volt', 'oocyte', 'human', '12', '20220134']
# 	Kv1.2/Kv1.5	['IC50', 'volt', 'oocyte', 'human', '47', '20220134']
# 	Kv1.2/Kv1.6	['IC50', 'volt', 'oocyte', 'human', '24', '20220134']
# 	Kv1.2/Kv1.7	['IC50', 'volt', 'oocyte', 'human', '3150', '20220134']
#
# P0C615	PDB:None
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '640/66', '20403399']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '>640', '20403399']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'human', '640/58', '20403399']
#
# P0C1X2	PDB:1Y62,2CA7
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '502', '15833744']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'human', '>20000', '22438204']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '3400', '22438204']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'human', '>100000', '22438204']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '>50000', '22438204']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv1.7	['IC50', 'patch', 'mammal', 'mouse', '439', '22438204']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv2.2	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv3.2	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv3.4	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'rat', '>30000', '22438204']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'mouse', '10000/0', '22438204']
#
# P83047	PDB:1NXN
# 	Kv1.1	['IC50', 'radio', 'mammal', 'human', '>600000', '12646193']
# 	Kv1.2	['IC50', 'radio', 'mammal', 'human', '>600000', '12646193']
#
# Q7YZS9	PDB:1ZJS
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1590', '12893060']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '>2000', '12893060']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '2090', '12893060']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '12893060']
# 	Kir2.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '12893060']
#
# A0A016UNP9	PDB:2MD0
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '>1500', '24891519']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'human', '266', '24891519']
#
# O15263	PDB:1E4Q,1FD3,1FD4,1FQQ
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '1000/16', '25238780']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'human', '0,022', '25238780']
# 	Kv7.1	['IC50', 'patch', 'mammal', 'human', '1000/12', '25238780']
# 	KCa1.1	['EC50', 'patch', 'mammal', 'human', '1,4', '23734009']
#
# Q53I06	PDB:1ZFU,3E7R,3E7U
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '1000/16', '25568977']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '1000/4', '25568977']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'human', '2800', '25568977']
# 	Kv7	['IC50', 'patch', 'mammal', 'human', '1000/3', '25568977']
# 	Kv11	['IC50', 'patch', 'mammal', 'human', '1000/4', '25568977']
# 	KCa2.3	['IC50', 'patch', 'mammal', 'human', '1000/6', '25568977']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '1000/7', '25568977']

# %%
# Only ligands with activity relative to any 2 of kv1.1 - kv1.3 ligands with 3D structure
part_3d = dict() 
for uid in kalium:
    targets = list(kalium[uid].exp.keys())
    if  ((("Kv1.1" in targets) and ("Kv1.3" in targets)) or 
            (("Kv1.1" in targets) and ("Kv1.2" in targets)) or
            (("Kv1.2" in targets) and ("Kv1.3" in targets))):
        if (kalium[uid].pdb != None):
            part_3d.update({uid: kalium[uid]})

print (len(part_3d))
for i in part_3d:
    print (part_3d[i])
# Out:
# 51
# Q9PWF3	PDB:1H5O,1Z99
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '369', '22498659']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '386', '22498659']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '287', '22498659']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '22498659']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>3000', '22498659']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '22498659']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '>3000', '22498659']
#
# P00980	PDB:1DTX
# 	Kv1.1	['EC50', 'patch', 'mammal', 'mouse', '9,4', '9134213']
# 	Kv1.2	['EC50', 'volt', 'oocyte', 'rat', '0,38', '1921987']
# 	Kv1.3	['EC50', 'volt', 'oocyte', 'rat', '>100', '1921987']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>200', '2555158']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>200', '2361015']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '9', '2361015']
# 	Kv3.1	['IC50', 'patch', 'oocyte', 'rat', '>100', '1378392']
# 	Kv3.2	['IC50', 'patch', 'oocyte', 'rat', '>100', '1378392']
# 	Kv3.4	['IC50', 'patch', 'oocyte', 'rat', '>100', '1378392']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>300', '1722463']
# 	Kir1.1	['Kd', 'volt', 'oocyte', 'rat', '>150', '9778362']
#
# A0A1Z0YU59	PDB:5M4V
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '8200', '201620454']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv1.5	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv3.1	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Kv11.1	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', None, '>10000', '201620454']
#
# P00981	PDB:1DTK
# 	Kv1	['Ki', 'radio', 'mammal', 'rat', '0,29', '10429207']
# 	Kv1.1	['EC50', 'patch', 'mammal', 'mouse', '0,03', '9134213']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>3', '8612784']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '>3', '8612784']
#
# P00979	PDB:1DEM,1DEN
# 	Kv1.1	['EC50', 'patch', 'mammal', 'mouse', '7,4', '9134213']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'mouse', '0,13', '7816560']
# 	Kv1.3	[None, 'patch', 'mammal', 'human', '>100', '8505626']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'human', '>1000', '9618407']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '10/26', '8612784']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '>300', '1722463']
#
# P24662	PDB:1KTX,1XSW,2KTX,2UVS,3ODV
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '1.1', '20007782']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '20', '20007782']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '0.1', '20007782']
# 	KCa1.1	['Kd', 'volt', 'oocyte', 'mouse', '1560', '20007782']
#
# P59847	PDB:1HLY
# 	Kv1.1	['IC50', 'flux', 'mammal', None, '0.031', '9446567']
# 	Kv1.2	['IC50', 'flux', 'mammal', None, '0.17', '9446567']
# 	Kv1.3	['IC50', 'flux', 'mammal', None, '0.086', '9446567']
# 	Kv1.6	['IC50', 'flux', 'mammal', None, '6', '9446567']
#
# P40755	PDB:1MTX
# 	Shaker	['Kd', None, None, 'fly', '160', '10.1023/A:1017062613503']
# 	Kv1.1	['Kd', 'patch', 'mammal', 'human', '4.2', '24878374']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'human', '0.006', '24878374']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '0.011', '24878374']
#
# P08815	PDB:1SXM
# 	Shaker	['Kd', None, None, 'fly', '160', '10.1023/A:1017062613503']
# 	Kv1.1	['Kd', 'patch', 'mammal', 'mouse', '>25', '7517498']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'rat', '2', '7517498']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'mouse', '1', '7517498']
# 	Kv1.5	['Kd', 'patch', 'mammal', 'human', '>25', '7517498']
# 	KCa1.1	['Kd', None, None, 'rat', '450', '10.1023/A:1017062613503']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'mouse', '>25', '7517498']
#
# O46028	PDB:1PJV
# 	Shaker	['Kd', 'patch', 'insect', 'fly', '700', '9688256']
# 	Kv1	['Ki', 'radio', 'mammal', 'rat', '0.109', '9688256']
# 	Kv1.1	['Kd', 'patch', 'mammal', 'mouse', '24400', '14498829']
# 	Kv1.2	['Kd', 'patch', 'mammal', 'rat', '27', '14498829']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'mouse', '5300', '14498829']
# 	KCa2	['IC50', 'radio', 'mammal', 'rat', '7200', '14498829']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'human', '484', '14498829']
#
# P82850	PDB:1HP9
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '>40000', '12034709']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '150000', '12034709']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '40000', '12034709']
#
# P59867	PDB:1QUZ,1WPD,1Y2P
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '0.001', '9359871']
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '7', '15498765']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'rat', '>100', '15498765']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '0.012', '9359871']
# 	Kv1.4	['IC50', 'patch', 'mammal', 'human', '>100', '16247791']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'human', '>100', '16247791']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '5000/35', '18687312']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'human', '>100', '16247791']
# 	KCa2	['IC50', 'radio', 'mammal', 'rat', '>1000', '9359871']
# 	KCa2.2	['IC50', 'patch', 'mammal', 'rat', '>100', '16247791']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '625', '15498765']
#
# P13487	PDB:1BAH,1CMR,2A9H,2CRD,4JTA,4JTC,4JTD
# 	Shaker	['Ki', 'volt', 'oocyte', 'fly', '227', '8204618']
# 	Kv1.1	['Ki', 'volt', 'oocyte', 'rat', '1500', '8204618']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '9', '20007782']
# 	Kv1.3	['Ki', 'volt', 'oocyte', 'rat', '0.19', '8204618']
# 	Kv1.6	['Ki', 'volt', 'oocyte', 'rat', '22', '8204618']
# 	Kv2.1	['Ki', 'volt', 'oocyte', 'rat', '>2000', '8204618']
# 	KCa1.1	['Kd', 'volt', 'oocyte', 'mouse', '3.5', '20007782']
# 	KCa3.1	['Kd', None, None, 'human', '5', '10.1023/A:1017062613503']
#
# P46111	PDB:1AGT
# 	Shaker	['Ki', 'volt', 'oocyte', 'fly', '0.64', '8204618']
# 	Kv1.1	['Ki', 'volt', 'oocyte', 'rat', '0.044', '8204618']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '3.4', '20007782']
# 	Kv1.3	['Ki', 'volt', 'oocyte', 'rat', '0.004', '8204618']
# 	Kv1.6	['Ki', 'volt', 'oocyte', 'rat', '0.037', '8204618']
# 	Kv2.1	['Ki', 'volt', 'oocyte', 'rat', '>2000', '8204618']
#
# Q9NII7	PDB:1BKT,2K4U,2MLA,2MLD
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '2000/21', '20713119']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '0.2', '9354615']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '2000/100', '20713119']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '2000/73', '20713119']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '2000/100', '20713119']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>2000', '20713119']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>2000', '20713119']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '2000/91', '20713119']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '20713119']
# 	Kv4.3	['IC50', 'volt', 'oocyte', 'rat', '>2000', '20713119']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '20713119']
#
# Q9U8D2	PDB:1WM7
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '3000/70', '20889474']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '467', '20889474']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '133', '20889474']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>3000', '20889474']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '20889474']
# 	KCa2	['Kd', 'radio', 'mammal', 'rat', '1000/4', '9151979']
#
# Q9NJP7	PDB:1DU9
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '20440', '22239942']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1950', '22239942']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '4400', '22239942']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '7', '22239942']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '22239942']
# 	KCa2	['Kd', 'radio', 'mammal', 'rat', '1000/12', '9151979']
#
# Q9U8D1	PDB:1WM8
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '4640', '22239942']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '5480', '22239942']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '530', '22239942']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '85.4', '22239942']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '22239942']
# 	KCa2	['Kd', 'radio', 'mammal', 'rat', '1000/42', '9151979']
#
# P83407	PDB:1Q2K,1R1G,3E8Y
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>100', '15178692']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '>100', '15178692']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '>100', '15178692']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>100', '15178692']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'human', '>10000', '15178692']
# 	KCa2.2	['IC50', 'patch', 'mammal', 'rat', '1000/62', '15178692']
#
# P0DL65	PDB:2RTZ
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>50000', '25514171']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '15.6', '25514171']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '12500', '25514171']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '0.054', '25514171']
#
# P0C1Z4	PDB:1WQE
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'rat', '500000/33', '15631621']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'rat', '500000/8', '15631621']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '500000/70', '15631621']
#
# P55896	PDB:1SCO,2CK4,2CK5
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '0.6', '15588251']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '5.4', '15588251']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '0.014', '15588251']
# 	Kv1.4	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	Kv1.6	['IC50', 'patch', 'mammal', None, '>1000', '15588251']
# 	Kv1.7	['IC50', 'patch', 'mammal', 'mouse', '>1000', '15588251']
# 	Kv3.1	['IC50', 'patch', 'mammal', 'mouse', '>1000', '15588251']
# 	Kv3.2	['IC50', 'patch', 'mammal', 'rat', '>1000', '16234482']
# 	Kv11	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	KCa2.1	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	KCa2.2	['IC50', 'patch', 'mammal', 'rat', '>1000', '15588251']
# 	KCa2.3	['IC50', 'patch', 'mammal', 'human', '>1000', '15588251']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '225', '15588251']
#
# Q10726	PDB:1WZ5
# 	Shaker	['Kd', 'patch', 'insect', 'fly', '32', '9001397']
# 	Kv1	['IC50', 'flux', 'mammal', 'rat', '100', '8913348']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>5000', '10931199']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '0.44', '10931199']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '9.7', '9464266']
# 	KCa2.2	['Kd', 'patch', 'mammal', 'human', '100', '11527975']
# 	KCa2.3	['Kd', 'patch', 'mammal', 'human', '250', '11527975']
#
# P58498	PDB:1N8M
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '3', '12919322']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>10000', '12919322']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '0.008', '12919322']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '>10000', '12919322']
# 	KCa2	['IC50', 'volt', 'mammal', 'rat', '500', '12919322']
#
# P55927	PDB:2PTA
# 	Shaker	['Kd', 'patch', 'insect', 'fly', '8.2', '8660410']
# 	Kv1	['IC50', 'flux', 'mammal', 'rat', '6', '8913348']
# 	Kv1.2	['IC50', 'volt', 'mammal', None, '0.032', '8913348']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '0.044', '11155206']
#
# P80719	PDB:1TXM,1WPD,1WT7
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '2.4', '10888198']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '0.2', '9022673']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '45', '9136903']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '0.8', '9136903']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '180', '9136903']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'human', '>1000', '12527813']
# 	KCa2	['IC50', 'radio', 'mammal', 'rat', '5', '9022673']
# 	KCa2.2	['Kd', 'patch', 'mammal', 'human', '1000', '11527975']
# 	KCa2.3	['Kd', 'patch', 'mammal', 'human', '>1000', '11527975']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '1', '12527813']
#
# P46114	PDB:1HP2
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '1000/97', '24590385']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1000/85', '24590385']
# 	Kv1.2	['Kd', None, None, 'mouse', '0.2', '10.1023/A:1017062613503']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '1000/85', '24590385']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '1000/94', '24590385']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv7.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv7.2	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>5000', '18687312']
#
# P59936	PDB:1C55,1C56,1WT7
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '1000/80', '24590385']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '46', '12630699']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1000/9', '24590385']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '6.19', '24590385']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '0.55', '24590385']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '1000/25', '24590385']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '1000/20', '24590385']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'rat', '>1000', '24590385']
# 	Kv7.1	['IC50', 'volt', 'oocyte', 'rat', '1000/5', '24590385']
# 	Kv7.2	['IC50', 'volt', 'oocyte', 'rat', '1000/14', '24590385']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '1000/11', '24590385']
#
# P0C174	PDB:2MSF
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '3000/25', '27706049']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '17100', '27706049']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'rat', '>3000', '27706049']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '>3000', '27706049']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '3000/25', '27706049']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'human', '3000/15', '27706049']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '3000/12', '27706049']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '3000/10', '27706049']
#
# P0DL37	PDB:6MZT
# 	Kv1.1	['IC50', 'patch', 'mammal', 'human', '253', '24723491']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '0.16', '24723491']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'human', '91', '24723491']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'human', '>10', '24723491']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '70', '24723491']
#
# P0DJ31	PDB:2K9O
# 	Kv1.1	['Kd', 'volt', 'mammal', 'mouse', '0.8', '22622363']
# 	Kv1.2	['Kd', 'volt', 'mammal', 'human', '0.54', '22622363']
# 	Kv1.3	['Kd', 'patch', 'mammal', 'human', '0.003', '22622363']
# 	Kv1.4	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	Kv1.5	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	Kv2.1	['Kd', 'volt', 'mammal', 'rat', '>10', '22622363']
# 	Kv11.1	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	KCa1.1	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	KCa2.3	['Kd', 'volt', 'mammal', 'human', '>10', '22622363']
# 	KCa3.1	['Kd', 'volt', 'mammal', 'human', '0.59', '22622363']
#
# P84835	PDB:2WH9
# 	Kv1.2	['Kd', 'volt', 'mammal', 'human', '>4000', '16567526']
# 	Kv1.3	['Kd', 'volt', 'mammal', 'human', '>4000', '16567526']
# 	Kv1.5	['Kd', 'volt', 'mammal', 'human', '>4000', '16567526']
# 	Kv2.1	['Kd', 'volt', 'mammal', 'human', '5,1', '16567526']
# 	Kv2.2	['Kd', 'volt', 'mammal', 'human', '2,6', '16567526']
# 	Kv3.2	['Kd', 'volt', 'mammal', 'human', '>4000', '16567526']
# 	Kv4.3	['Kd', 'volt', 'mammal', 'human', '54', '16567526']
#
# P62520	PDB:2I1T
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>1000', '15084603']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>1000', '15084603']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>1000', '15084603']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '5000/95', '17150181']
#
# P0C247	PDB:2A2V
# 	Kv1.1	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv1.2	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv1.3	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv1.4	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv2.1	['Kd', 'volt', 'oocyte', None, '760', '17176080']
# 	Kv3.1	['Kd', 'volt', 'oocyte', None, '>5000', '17176080']
# 	Kv4.1	['Kd', 'volt', 'oocyte', None, '5000/35', '17176080']
# 	Kv4.2	['Kd', 'volt', 'oocyte', None, '5000/42', '17176080']
#
# P56852	PDB:1D1H
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>500', '7576642']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>500', '7576642']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '>500', '7576642']
# 	Kv2.1	['Kd', 'volt', 'oocyte', 'human', '102', '9136775']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'mouse', '>500', '7576642']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'rat', '100', '9136775']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'fly', '>500', '7576642']
# 	Shaker-IR	['IC50', 'volt', 'oocyte', 'fly', '6000', '9136775']
#
# P68425	PDB:2JOT
# 	Kv1	['IC50', 'patch', 'mammal', 'rat', '11,6', '18923708']
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '5000/78', '18923708']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '5000/10', '18923708']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '5000/28', '18923708']
#
# P60992	PDB:2N6O
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '300/12', '12065754']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'mouse', '300/4', '12065754']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'mouse', '300/3', '12065754']
# 	Kv1.4	['IC50', 'patch', 'mammal', 'mouse', '300/4', '12065754']
# 	Kv1.5	['IC50', 'patch', 'mammal', 'mouse', '300/2', '12065754']
# 	Kv1.6	['IC50', 'patch', 'mammal', 'mouse', '300/1', '12065754']
# 	Kv2.1	['IC50', 'patch', 'mammal', 'mouse', '100/23', '12065754']
# 	Kv2.2	['IC50', 'patch', 'mammal', 'mouse', '100/19,7', '12065754']
# 	Kv3.4	['IC50', 'patch', 'mammal', 'mouse', '300/4', '12065754']
# 	Kv4.1	['IC50', 'patch', 'mammal', 'mouse', '280', '12065754']
# 	Kv4.2	['IC50', 'patch', 'mammal', 'mouse', '300/39', '12065754']
# 	Kv4.3	['IC50', 'patch', 'mammal', 'mouse', '300/43', '12065754']
# 	Kv7.1	['IC50', 'patch', 'mammal', 'mouse', '300/8', '12065754']
#
# P61230	PDB:1V7F
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>5000', '10051143']
# 	Kv1.5	['IC50', 'patch', 'mammal', None, '>5000', '10051143']
# 	Kv2.1	['IC50', 'patch', 'mammal', None, '500/6', '10051143']
# 	Kv2.2	['IC50', 'patch', 'mammal', None, '500/16', '10051143']
# 	Kv3.1	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	Kv3.2	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	Kv3.4	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	Kv4.1	['IC50', 'patch', 'mammal', 'mouse', '250/39', '10051143']
# 	Kv4.2	['IC50', 'patch', 'mammal', 'rat', '5', '10051143']
# 	Kv4.3	['IC50', 'patch', 'mammal', 'rat', '28', '10051143']
# 	Kv7.1	['IC50', 'patch', 'mammal', None, '>300', '10051143']
# 	Kv11.1	['IC50', 'patch', 'mammal', None, '>300', '10051143']
# 	Kir2.1	['IC50', 'volt', 'oocyte', None, '>1000', '10051143']
# 	K2p2.1	['IC50', 'patch', 'mammal', None, '>1000', '10051143']
#
# P83480	PDB:2M9L
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '730/6', '12475222']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '730/40', '12475222']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '730/7', '12475222']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'human', '730/60', '12475222']
#
# P83476	PDB:2N9T,5O0U,5TCZ
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '>460', '12475222']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '460/2', '12475222']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '460/-2', '12475222']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'human', '460/5', '12475222']
#
# P11494	PDB:1BDS,2BDS
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '10000/19', '9506974']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '10000/17', '9506974']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv1.5	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv2.2	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv3.1	['IC50', 'volt', 'oocyte', None, '10000/22', '9506974']
# 	Kv3.2	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv3.3	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv3.4	['IC50', 'volt', 'mammal', None, '47', '9506974']
# 	Kv4.2	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kv4.3	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kir1.1	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kir2.1	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
# 	Kir2.2	['IC50', 'volt', 'oocyte', None, '>10000', '9506974']
#
# P61541	PDB:1WQK
# 	Kv1.1	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv1.2	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv1.3	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv1.4	['IC50', 'patch', 'mammal', None, '1000/35', '12815161']
# 	Kv1.5	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv1.6	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv2.1	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv3.4	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv4.2	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv7.1	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv7.2	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv7.3	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv10.1	['IC50', 'patch', 'mammal', None, '>100', '12815161']
# 	Kv11.1	['IC50', 'patch', 'mammal', None, '34', '12815161']
# 	Kv11.2	['Kd', 'volt', 'oocyte', None, '>1000', '17473056']
# 	Kv12.3	['IC50', 'patch', 'mammal', None, '>100', '12815161']
#
# P29186	PDB:1BGK
# 	Kv1.1	['Kd', 'volt', 'oocyte', 'human', '6', '9063464']
# 	Kv1.2	['Kd', 'volt', 'oocyte', 'human', '15', '9063464']
# 	Kv1.3	['Kd', 'volt', 'oocyte', 'human', '10', '9063464']
# 	Kv3.1	['Kd', 'volt', 'oocyte', 'human', '>125', '9063464']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'human', '172', '10419508']
#
# P29187	PDB:1BEI,1C2U,1ROO,2K9E,4LFQ,4LFS,4Z7P,5I5A,5I5B,5I5C
# 	Shaker	['Ki', 'volt', 'oocyte', 'fly', '2', '26627718']
# 	Kv1	['IC50', 'radio', 'mammal', 'rat', '0,02', '7660365']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'mouse', '0,016', '9830012']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'rat', '9', '9830012']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'mouse', '0,011', '9830012']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'mouse', '0,312', '9830012']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '>100', '9830012']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'human', '0,165', '9830012']
# 	Kv1.7	['IC50', 'volt', 'oocyte', 'mouse', '11,5', '9830012']
# 	Kv2.1	['IC50', 'patch', 'mammal', 'human', '>1000', '15709110']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'mouse', '>100', '9830012']
# 	Kv3.2	['IC50', 'patch', 'mammal', 'human', '6', '15709110']
# 	Kv3.4	['IC50', 'volt', 'oocyte', 'rat', '>100', '9830012']
# 	KCa3.1	['Kd', 'patch', 'mammal', 'human', '172', '10419508']
# 	KcsA-Shaker	['Ki', 'volt', 'oocyte', None, '50', '26627718']
#
# Q0N4U8	PDB:2FQC,2NAV,2NAW
# 	Kv1.1	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.2	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.3	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.4	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.5	['IC50', 'volt', 'oocyte', None, '>1000', '16819832']
# 	Kv1.6	['IC50', 'volt', 'oocyte', None, '1590', '16819832']
# 	Kv2.1	['IC50', 'volt', 'oocyte', None, '>2000', '16819832']
# 	Kv3.4	['IC50', 'volt', 'oocyte', None, '>2000', '16819832']
#
# P0C1X2	PDB:1Y62,2CA7
# 	Shaker	['IC50', 'volt', 'oocyte', 'fly', '502', '15833744']
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'human', '>20000', '22438204']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '3400', '22438204']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv1.4	['IC50', 'volt', 'oocyte', 'human', '>100000', '22438204']
# 	Kv1.5	['IC50', 'volt', 'oocyte', 'human', '>50000', '22438204']
# 	Kv1.6	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv1.7	['IC50', 'patch', 'mammal', 'mouse', '439', '22438204']
# 	Kv2.1	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv2.2	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv3.1	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv3.2	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv3.4	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv4.2	['IC50', 'volt', 'oocyte', 'human', '10000/0', '22438204']
# 	Kv10.1	['IC50', 'volt', 'oocyte', 'rat', '>30000', '22438204']
# 	KCa1.1	['IC50', 'patch', 'mammal', 'mouse', '10000/0', '22438204']
#
# P83047	PDB:1NXN
# 	Kv1.1	['IC50', 'radio', 'mammal', 'human', '>600000', '12646193']
# 	Kv1.2	['IC50', 'radio', 'mammal', 'human', '>600000', '12646193']
#
# Q7YZS9	PDB:1ZJS
# 	Kv1.1	['IC50', 'volt', 'oocyte', 'rat', '1590', '12893060']
# 	Kv1.2	['IC50', 'volt', 'oocyte', 'human', '>2000', '12893060']
# 	Kv1.3	['IC50', 'volt', 'oocyte', 'rat', '2090', '12893060']
# 	Kv11.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '12893060']
# 	Kir2.1	['IC50', 'volt', 'oocyte', 'human', '>2000', '12893060']
#
# A0A016UNP9	PDB:2MD0
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '>1500', '24891519']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'human', '266', '24891519']
#
# O15263	PDB:1E4Q,1FD3,1FD4,1FQQ
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '1000/16', '25238780']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'human', '0,022', '25238780']
# 	Kv7.1	['IC50', 'patch', 'mammal', 'human', '1000/12', '25238780']
# 	KCa1.1	['EC50', 'patch', 'mammal', 'human', '1,4', '23734009']
#
# Q53I06	PDB:1ZFU,3E7R,3E7U
# 	Kv1.1	['IC50', 'patch', 'mammal', 'mouse', '1000/16', '25568977']
# 	Kv1.2	['IC50', 'patch', 'mammal', 'human', '1000/4', '25568977']
# 	Kv1.3	['IC50', 'patch', 'mammal', 'human', '2800', '25568977']
# 	Kv7	['IC50', 'patch', 'mammal', 'human', '1000/3', '25568977']
# 	Kv11	['IC50', 'patch', 'mammal', 'human', '1000/4', '25568977']
# 	KCa2.3	['IC50', 'patch', 'mammal', 'human', '1000/6', '25568977']
# 	KCa3.1	['IC50', 'patch', 'mammal', 'human', '1000/7', '25568977']

# %%
from fractions import Fraction
float("0.3")
# Out:
# 0.3
